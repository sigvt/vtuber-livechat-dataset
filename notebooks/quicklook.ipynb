# %%
from setup import *

(channels, _) = load_hololive()

# %%
channels.head()
# Out:
#                   channelId                name  englishName affiliation  \
# 0  UCp6993wxpyDPHUpavwDFqgg  SoraCh. ときのそらチャンネル  Tokino Sora    Hololive
# 1  UCp6993wxpyDPHUpavwDFqgg  SoraCh. ときのそらチャンネル  Tokino Sora    Hololive
# 2  UCp6993wxpyDPHUpavwDFqgg  SoraCh. ときのそらチャンネル  Tokino Sora    Hololive
# 3  UCp6993wxpyDPHUpavwDFqgg  SoraCh. ときのそらチャンネル  Tokino Sora    Hololive
# 4  UCp6993wxpyDPHUpavwDFqgg  SoraCh. ときのそらチャンネル  Tokino Sora    Hololive
#
#       group  subscriptionCount  videoCount  \
# 0  No Group             961000         602
# 1  No Group             961000         602
# 2  No Group             961000         602
# 3  No Group             961000         602
# 4  No Group             961000         602
#
#                                                photo   period     chats  ...  \
# 0  https://yt3.ggpht.com/ytc/AKedOLRo4fRoifdnGRyv...  2021-03  389559.0  ...
# 1  https://yt3.ggpht.com/ytc/AKedOLRo4fRoifdnGRyv...  2021-04  310844.0  ...
# ...
