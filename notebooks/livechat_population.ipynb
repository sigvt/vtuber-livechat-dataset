# %%
from setup import *

(channels, _) = load_hololive()

# %%
annotation_threshold = 55000
avatar_size = 24


def plot(data, line_color='red'):
    chart = Chart(data,
                title=TitleParams('Live Chat Population (2021/10)',
                                    fontSize=25)).mark_image(
                                        cornerRadius=15,
                                        clip=True,
                                        width=avatar_size,
                                        height=avatar_size).encode(
                                            X('subscriptionCount',
                                            title='Subscribers',
                                            axis=Axis(format='~s')),
                                            Y('uniqueChatters',
                                            title='Unique Chatters',
                                            axis=Axis(format='~s')),
                                            url='photo').properties(width=600,
                                                                    height=500)

    # trendline
    chart = chart + chart.transform_regression(
        'subscriptionCount', 'uniqueChatters',
        method='quad').mark_line(color=line_color)

    # annotation
    chart = chart + Chart(data).mark_text(
        align='left', baseline='middle', fontSize=20, dx=20, dy=-5).encode(
            X('subscriptionCount'),
            Y('uniqueChatters'),
            Text('uniqueChatters', format='~s'),
        ).transform_filter(
            datum['uniqueChatters'] > annotation_threshold) + Chart(data).mark_text(
                align='left',
                baseline='middle',
                fontSize=10,
                dx=20,
                dy=10).transform_calculate(
                    subc=f'{datum.subscriptionCount} + " Subs"').encode(
                        X('subscriptionCount'),
                        Y('uniqueChatters'),
                        Text('subscriptionCount', format='~s'),
                        # text=Text('subc', type='nominal')
                    ).transform_filter(
                        datum['uniqueChatters'] > annotation_threshold)

    return chart

def add_footer(chart):
    # footer
    def footer(chart, title, anchor='end'):
        return alt.concat(chart).properties(title=TitleParams(title,
                                                            anchor=anchor,
                                                            baseline='bottom',
                                                            orient='bottom',
                                                            fontWeight='normal',
                                                            fontSize=10))

    chart = footer(chart, [
        'Data Source: VTuber 500M',
        'https://www.kaggle.com/uetchy/vtuber-livechat'
    ])
    chart = footer(chart, 'holodata.org', 'start')

    return chart

# subset = overall.sort_values('uniqueChatters', ascending=False).groupby('group').head(1).reset_index(drop=True)
subset = channels.query('period == "2021-10"')

en = subset[subset['group'].str.contains('English')]
indonesia = subset[subset['group'].str.contains('Indonesia')]
jp = subset[~(subset['group'].str.contains('English') | subset['group'].str.contains('Indonesia'))]

chart = add_footer(plot(jp) + plot(indonesia, line_color='yellow') + plot(en, line_color='#8658FF'))
chart
# Out:
# alt.ConcatChart(...)

# %%
jp
# Out:
#                     channelId                    name        englishName  \
# 8    UCp6993wxpyDPHUpavwDFqgg      SoraCh. ときのそらチャンネル        Tokino Sora
# 17   UCDqI2jOz0weumE8s7paEk6g        Roboco Ch. - ロボ子         Roboco-san
# 26   UC0TXe_LYZ4scaW2XMyi5_kw            AZKi Channel               AZKi
# 36   UC5CwaMl1eIgY8h02uZw7u8A          Suisei Channel  Hoshimachi Suisei
# 46   UC-hM6YJuNYVAmUWxeIr9FeA          Miko Ch. さくらみこ        Sakura Miko
# 50   UC8rcEBzJSleTkf_-agPM20g    IRyS Ch. hololive-EN               IRyS
# 60   UC1CfXB_kRs3C-zaeTG3oGyg       HAACHAMA Ch 赤井はあと         Akai Haato
# 69   UCD8HOxPs4Xvsm8H0ZxXGiBw   Mel Channel 夜空メルチャンネル         Yozora Mel
# 79   UCdn5BQ06XqgXoAxIhbqw5Rg             フブキCh。白上フブキ   Shirakami Fubuki
# 88   UCFTLzh12_nrtzqBPsTCqenA   アキロゼCh。Vtuber/ホロライブ所属      Aki Rosenthal
# 17     Hololive           No Group             763000         816
# 26     Hololive           No Group             528000         208
# 36     Hololive           No Group            1200000         414
# 46     Hololive           No Group            1260000         592
# 50     Hololive           No Group             686000          88
# 60     Hololive     1st Generation            1290000         634
# 69     Hololive     1st Generation             627000         181
# 79     Hololive     1st Generation            1650000        1228
# 88     Hololive     1st Generation             601000         484
# 98     Hololive     1st Generation            1140000         605
# 108    Hololive     2nd Generation            1420000         384
# 117    Hololive     2nd Generation             756000         335
# 125    Hololive     2nd Generation            1150000         188
# 135    Hololive     2nd Generation            1160000         466
# 144    Hololive     2nd Generation             900000         376
# 154    Hololive             GAMERS            1710000         466
# 163    Hololive             GAMERS             875000         368
# 173    Hololive             GAMERS            1220000         442
# 183    Hololive     3rd Generation            1760000         752
# 193    Hololive     3rd Generation            1670000         650
# 202    Hololive     3rd Generation            1340000         518
# 212    Hololive     3rd Generation            1450000         402
# 221    Hololive     3rd Generation             792000         687
# 230    Hololive     4th Generation             844000         535
# 239    Hololive     4th Generation             721000         438
# 249    Hololive     4th Generation            1080000         686
# 259    Hololive     4th Generation            1070000         686
# 269    Hololive     5th Generation             803000         376
# 278    Hololive     5th Generation             844000         470
# 288    Hololive     5th Generation             852000         488
# 298    Hololive     5th Generation            1010000         442
# 428    Hololive  Holostars 1st Gen             109000         465
# 437    Hololive  Holostars 1st Gen             193000         418
# 446    Hololive  Holostars 1st Gen             140000         923
# 455    Hololive  Holostars 1st Gen             157000         318
# 464    Hololive  Holostars 2nd Gen             220000         911
# 473    Hololive  Holostars 2nd Gen             108000         606
# 482    Hololive  Holostars 2nd Gen             169000         483
# 491    Hololive  Holostars 3rd Gen             171000         338
# 500    Hololive  Holostars 3rd Gen             143000         356
#
#                                                  photo   period    chats  ...  \
# 8    https://yt3.ggpht.com/ytc/AKedOLQO9Vyz7ysAwPSi...  2021-10   323865  ...
# 17   https://yt3.ggpht.com/ytc/AKedOLTVWKjrovP0tGtg...  2021-10   248847  ...
# 26   https://yt3.ggpht.com/ytc/AKedOLQQhnWKHLOLxjnX...  2021-10     4747  ...
# 36   https://yt3.ggpht.com/ytc/AKedOLSAm13gTESsu39z...  2021-10   509207  ...
# 46   https://yt3.ggpht.com/ytc/AKedOLRNGCUT1awYh91C...  2021-10  1952748  ...
# 50   https://yt3.ggpht.com/UwxlX1PuB_RwJyEUW_ofbBR6...  2021-10  1015726  ...
# 60   https://yt3.ggpht.com/rNj6bichsOoUjA2N9iXWxInE...  2021-10   157980  ...
# 69   https://yt3.ggpht.com/ytc/AKedOLSwGrjnpZYhSj5y...  2021-10   188135  ...
# 79   https://yt3.ggpht.com/ytc/AKedOLQWDSaTmBOPMp-z...  2021-10   761939  ...
# 88   https://yt3.ggpht.com/ytc/AKedOLT4XEPRFwXpb4gZ...  2021-10   171008  ...
# 98   https://yt3.ggpht.com/ytc/AKedOLQCXDfJbZoEZ-gt...  2021-10   319466  ...
# 108  https://yt3.ggpht.com/ytc/AKedOLTbU5ET3bgn0Iuz...  2021-10   648076  ...
# 117  https://yt3.ggpht.com/ytc/AKedOLQn_VxZ1ApMgQah...  2021-10    75836  ...
# 125  https://yt3.ggpht.com/ytc/AKedOLT7tdqZvDuxprLy...  2021-10    52180  ...
# 135  https://yt3.ggpht.com/ytc/AKedOLRaQJl61Pxhsnrz...  2021-10  1609828  ...
# 125         692                  652   1647107       2380               14791
# 135        8180                 2408   8584606       1049              275119
# 144        2238                  732   2201122        983               47625
# 154        4148                 1521   5696206       1373              167716
# 163        1032                  463    722378        699               12600
# 173        3868                  866   2086112        539               99177
# 183        4986                 1198   5276541       1058               96555
# 193        2702                 1493   5179117       1916               85870
# 202        2562                  802   3410073       1331               98194
# 212        8888                 1488  11945001       1343              314156
# 221        2280                  604   3056356       1340               74548
# 230        1997                  649   2340114       1171               53313
# 239        2450                  911   3856286       1573               59415
# 249        4866                 1378   5317035       1092              195661
# 259        5010                  899   6165517       1230              139852
# 269        4096                  991   3802003        928               85260
# 278        8949                 1226   5782551        646              314903
# 288        2478                  459   1108085        447               51408
# 298        5361                 1531   4793571        894              165704
# 428        1046                  539   1830138       1749               17629
# 437         322                  175    544392       1690                7222
# 446         440                  177    257292        584                8131
# 455         524                  369   1081874       2064               10695
# 464         720                  353    512063        711                7320
# 473          46                   28     63395       1378                 786
# 482         277                  160    345821       1248                5511
# 491         444                  184    393141        885                7839
# 500         531                  150    325469        612               14557
#
#      averageMessageLength  mostFrequentCurrency  mostFrequentColor     sex  \
# 8                      18                   JPY              green  Female
# 17                     31                   JPY              green  Female
# 26                      9                   JPY              green  Female
# 36                     23                   JPY              green  Female
# 46                     28                   JPY              green  Female
# 50                     68                   USD              green  Female
# 60                     21                   JPY              green  Female
# 69                     33                   JPY              green  Female
# 79                     23                   JPY              green  Female
# 88                     25                   JPY              green  Female
# 98                     23                   JPY              green  Female
# 108                    31                   JPY              green  Female
# 117                    17                   JPY              green  Female
# 125                    25                   JPY              green  Female
# 135                    37                   JPY              green  Female
# 144                    24                   JPY              green  Female
# 154                    43                   JPY              green  Female
# 163                    16                   JPY              green  Female
# 173                    32                   JPY              green  Female
# 183                    23                   JPY              green  Female
# 193                    36                   JPY              green  Female
# 202                    41                   JPY              green  Female
# 212                    38                   JPY             yellow  Female
# 221                    36                   JPY              green  Female
# 230                    30                   JPY              green  Female
# 239                    26                   JPY              green  Female
# 249                    50                   JPY              green  Female
# 259                    32                   JPY          lightblue  Female
# 269                    25                   JPY              green  Female
# 278                    39                   JPY              green  Female
# 288                    22                   JPY          lightblue  Female
# 298                    35                   JPY          lightblue  Female
# 428                    20                   TWD              green    Male
# 437                    28                   JPY             yellow    Male
# 446                    20                   JPY              green    Male
# 455                    23                   JPY              green    Male
# 464                    12                   JPY              green    Male
# 473                    21                   JPY              green    Male
# 482                    26                   TWD              green    Male
# 491                    19                   JPY              green    Male
# 500                    27                   JPY              green    Male
#
#      language
# 8    Japanese
# 17   Japanese
# 26   Japanese
# 36   Japanese
# 46   Japanese
# 50    English
# 60   Japanese
# 69   Japanese
# 79   Japanese
# 88   Japanese
# 98   Japanese
# 108  Japanese
# 117  Japanese
# 125  Japanese
# 135  Japanese
# 144  Japanese
# 154  Japanese
# 163  Japanese
# 173  Japanese
# 183  Japanese
# 193  Japanese
# 202  Japanese
# 212  Japanese
# 221  Japanese
# 230  Japanese
# 239  Japanese
# 249  Japanese
# 259  Japanese
# 269  Japanese
# 278  Japanese
# 288  Japanese
# 298  Japanese
# 428  Japanese
# 437  Japanese
# 446  Japanese
# 455  Japanese
# 464  Japanese
# 473  Japanese
# 482  Japanese
# 491  Japanese
# 500  Japanese
#
# [41 rows x 25 columns]
