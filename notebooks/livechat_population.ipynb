# %%
from setup import *

(channels, _) = load_hololive()

# %%
annotation_threshold = 46600
avatar_size = 24


def plot(data, line_color='red'):
    chart = Chart(data,
                  title=TitleParams('Live Chat Population (2022/2)',
                                    fontSize=25)).mark_image(
                                        cornerRadius=15,
                                        clip=True,
                                        width=avatar_size,
                                        height=avatar_size).encode(
                                            X('subscriptionCount',
                                              scale=alt.Scale(
                                                  type='log',
                                                #   align=0.5,
                                                  bins=[
                                                      100000,
                                                      250000,
                                                      500000,
                                                      750000,
                                                      1000000,
                                                      1500000,
                                                      2000000,
                                                      3000000
                                                  ]),
                                              title='Subscribers',
                                              axis=Axis(format='~s')),
                                            Y(
                                                'uniqueChatters',
                                                # scale=alt.Scale(type='log'),
                                                title='Unique Chatters',
                                                axis=Axis(format='~s')),
                                            url='photo').properties(width=800,
                                                                    height=600)

    # trendline
    chart = chart + chart.transform_regression(
        'subscriptionCount', 'uniqueChatters',
        method='quad').mark_line(color=line_color)

    # annotation
    chart = chart + Chart(data).mark_text(
        align='left', baseline='middle', fontSize=20, dx=20, dy=-5).encode(
            X('subscriptionCount'),
            Y('uniqueChatters'),
            Text('uniqueChatters', format='~s'),
        ).transform_filter(
            datum['uniqueChatters'] > annotation_threshold) + Chart(
                data).mark_text(
                    align='left', baseline='middle', fontSize=10, dx=20,
                    dy=10).transform_calculate(
                        subc=f'{datum.subscriptionCount} + " Subs"').encode(
                            X('subscriptionCount'),
                            Y('uniqueChatters'),
                            Text('subscriptionCount', format='~s'),
                            # text=Text('subc', type='nominal')
                        ).transform_filter(
                            datum['uniqueChatters'] > annotation_threshold)

    return chart


def add_footer(chart):
    # footer
    def footer(chart, title, anchor='end'):
        return alt.concat(chart).properties(
            title=TitleParams(title,
                              anchor=anchor,
                              baseline='bottom',
                              orient='bottom',
                              fontWeight='normal',
                              fontSize=10))

    chart = footer(chart, [
        'Data Source: VTuber 1B',
        'https://www.kaggle.com/uetchy/vtuber-livechat'
    ])
    chart = footer(chart, 'holodata.org', 'start')

    return chart


# subset = overall.sort_values('uniqueChatters', ascending=False).groupby('group').head(1).reset_index(drop=True)
subset = channels.query('period == "2022-02"')

en = subset[subset['group'].str.contains('English')]
indonesia = subset[subset['group'].str.contains('Indonesia')]
jp = subset[~(subset['group'].str.contains('English')
              | subset['group'].str.contains('Indonesia'))]

chart = add_footer(
    plot(jp) + plot(indonesia, line_color='yellow') +
    plot(en, line_color='#8658FF'))
chart
# Out:
# alt.ConcatChart(...)

# %%
jp
# Out:
#                     channelId                    name        englishName  \
# 2    UCp6993wxpyDPHUpavwDFqgg      SoraCh. ときのそらチャンネル        Tokino Sora
# 15   UCDqI2jOz0weumE8s7paEk6g        Roboco Ch. - ロボ子         Roboco-san
# 28   UC0TXe_LYZ4scaW2XMyi5_kw            AZKi Channel               AZKi
# 42   UC5CwaMl1eIgY8h02uZw7u8A          Suisei Channel  Hoshimachi Suisei
# 647  UC9mf_ZVpouoILRY9NUIaK-w             Rikka ch.律可          Rikkaroid
# 660  UCKeAhJvy8zgXWbh9duVjIaQ      Aruran Ch. アルランディス        Arurandeisu
# 673  UCZgOv3YDEs-ZnZWDYVwJdmA         Izuru Ch. 奏手イヅル       Kanade Izuru
# 686  UCANDOlYTJT7N5jlRC3zfzVA        Roberu Ch. 夕刻ロベル      Yukoku Roberu
# 699  UCGNI4MENvnsymYjKiZwv9eg          Temma Ch. 岸堂天真      Kishido Temma
# 712  UCNVEsYbiZjH5QLmGeSgTSzg           astel ch.アステル         Astel Leda
# 725  UChSvpZYRPh0FvG4SJGSga3g          Shien Ch.影山シエン     Kageyama Shien
# 738  UCwL7dgTxKo8Y4RFIKWaf8gA            Oga Ch.荒咬オウガ        Aragami Oga
#
#     affiliation              group  subscriptionCount  videoCount  \
# 2      Hololive           No Group             940000         566
# 15     Hololive           No Group             814000         974
# 28     Hololive           No Group             579000         226
# 42     Hololive           No Group            1360000         470
# 56     Hololive           No Group            1390000         691
# 78     Hololive     1st Generation            1340000         722
# 91     Hololive     1st Generation             689000         263
# 105    Hololive     1st Generation            1850000        1387
# 118    Hololive     1st Generation             652000         526
# 132    Hololive     1st Generation            1210000         684
# 146    Hololive     2nd Generation            1530000         424
# 159    Hololive     2nd Generation             838000         413
# 172    Hololive     2nd Generation            1240000         203
# 185    Hololive     2nd Generation            1280000         572
# 198    Hololive     2nd Generation             979000         419
# 212    Hololive             GAMERS            1780000         505
# 225    Hololive             GAMERS             949000         449
# 239    Hololive             GAMERS            1320000         520
# 253    Hololive     3rd Generation            1880000         863
# 267    Hololive     3rd Generation            1840000         714
# 280    Hololive     3rd Generation            1430000         592
# 294    Hololive     3rd Generation            1610000         453
# 307    Hololive     3rd Generation             863000         803
# 320    Hololive     4th Generation             965000         629
# 333    Hololive     4th Generation             776000         431
# 347    Hololive     4th Generation            1170000         825
# 361    Hololive     4th Generation            1160000         814
# 375    Hololive     5th Generation             905000         447
# 388    Hololive     5th Generation             947000         593
# 402    Hololive     5th Generation             934000         593
# 416    Hololive     5th Generation            1090000         534
# 634    Hololive  Holostars 1st Gen             116000         510
# 647    Hololive  Holostars 1st Gen             201000         466
# 660    Hololive  Holostars 1st Gen             154000        1156
# 673    Hololive  Holostars 1st Gen             171000         360
# 686    Hololive  Holostars 2nd Gen             238000        1036
# 699    Hololive  Holostars 2nd Gen             114000         683
# 712    Hololive  Holostars 2nd Gen             184000         535
# 725    Hololive  Holostars 3rd Gen             187000         388
# 738    Hololive  Holostars 3rd Gen             154000         434
#
#                                                  photo   period      chats  \
# 2    https://yt3.ggpht.com/ytc/AKedOLQO9Vyz7ysAwPSi...  2021-04   310844.0
# 15   https://yt3.ggpht.com/ytc/AKedOLTVWKjrovP0tGtg...  2021-04   345636.0
# 28   https://yt3.ggpht.com/ytc/AKedOLQQhnWKHLOLxjnX...  2021-04   110020.0
# 712  ...       627.0                351.0   1131983.0     1805.0
# 725  ...       703.0                323.0   1211480.0     1723.0
# 738  ...       436.0                206.0    533470.0     1223.0
#
#      totalMessageLength  averageMessageLength  mostFrequentCurrency  \
# 2               15962.0                  24.0                   JPY
# 15              27401.0                  31.0                   JPY
# 28               9714.0                  20.0                   JPY
# 42              37047.0                  24.0                   JPY
# 56             123367.0                  23.0                   JPY
# 78              47828.0                  25.0                   JPY
# 91              12867.0                  43.0                   JPY
# 105             35042.0                  23.0                   JPY
# 118             68022.0                  39.0                   USD
# 132             42570.0                  20.0                   JPY
# 146             63788.0                  30.0                   JPY
# 159             11058.0                  24.0                   JPY
# 172             78444.0                  32.0                   JPY
# 185            170717.0                  33.0                   JPY
# 198             30812.0                  24.0                   JPY
# 212            236651.0                  39.0                   JPY
# 225             26716.0                  21.0                   JPY
# 239            181818.0                  33.0                   JPY
# 253            131088.0                  17.0                   JPY
# 267            181990.0                  24.0                   JPY
# 280            154770.0                  38.0                   JPY
# 294            397191.0                  32.0                   JPY
# 307            112555.0                  35.0                   JPY
# 320             63092.0                  31.0                   JPY
# 333             40820.0                  22.0                   JPY
# 347            204833.0                  43.0                   JPY
# 361            154914.0                  29.0                   JPY
# 375            170947.0                  28.0                   JPY
# 388            351498.0                  39.0                   JPY
# 402             29141.0                  24.0                   JPY
# 416            125920.0                  27.0                   JPY
# 634              1139.0                  16.0                   JPY
# 647              9020.0                  31.0                   JPY
# 660             19667.0                  32.0                   JPY
# 673              5673.0                  22.0                   JPY
# 686              6658.0                  18.0                   JPY
# 699             10014.0                  25.0                   USD
# 712             17102.0                  31.0                   USD
# 725             17426.0                  28.0                   JPY
# 738             11859.0                  29.0                   JPY
#
#      mostFrequentColor     sex  language
# 2                green  Female  Japanese
# 15               green  Female  Japanese
# 28               green  Female  Japanese
# 42               green  Female  Japanese
# 56               green  Female  Japanese
# 78               green  Female  Japanese
# 91               green  Female  Japanese
# 105              green  Female  Japanese
# 118              green  Female  Japanese
# 132              green  Female  Japanese
# 146              green  Female  Japanese
# 159              green  Female  Japanese
# 172              green  Female  Japanese
# 185              green  Female  Japanese
# 198              green  Female  Japanese
# 212              green  Female  Japanese
# 225              green  Female  Japanese
# 239              green  Female  Japanese
# 253              green  Female  Japanese
# 267              green  Female  Japanese
# 280              green  Female  Japanese
# 294              green  Female  Japanese
# 307              green  Female  Japanese
# 320              green  Female  Japanese
# 333              green  Female  Japanese
# 347              green  Female  Japanese
# 361          lightblue  Female  Japanese
# 375              green  Female  Japanese
# 388              green  Female  Japanese
# 402          lightblue  Female  Japanese
# 416          lightblue  Female  Japanese
# 634              green    Male  Japanese
# 647              green    Male  Japanese
# 660              green    Male  Japanese
# 673              green    Male  Japanese
# 686              green    Male  Japanese
# 699              green    Male  Japanese
# 712              green    Male  Japanese
# 725              green    Male  Japanese
# 738              green    Male  Japanese
#
# [40 rows x 25 columns]
